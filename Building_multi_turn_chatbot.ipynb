# %% [markdown]
# <a href="https://colab.research.google.com/github/mapsguy/programming-gemini/blob/main/Building_multi_turn_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step 1: install/upgrade the latest genai SDK
# %pip install google-genai --upgrade --quiet

# %%
#import the genai library
from google import genai

# %%
#step 2: AIStudio: read the api key from the user data
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GEMINI_API_KEY"))

#If you want to read from environment keys
#import os
#client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %%
model_name = "models/gemini-2.5-flash-preview-05-20"

# %%
#step 3: Conducting a conversation
from google.genai import types

gen_config = types.GenerateContentConfig(
    system_instruction="You are a friendly and helpful coding assistant."
)

chat_session = client.chats.create(
    model=model_name,
    config = gen_config,
    history=[],
)

response = chat_session.send_message("Hello! Can you help me with Python?")

print(response.text)
# Out:
# Hello there! Yes, absolutely! I'd be happy to help you with Python.
#
# Python is a fantastic language. To get started, could you tell me a little bit about what you're looking for help with? For example:
#
# *   Are you just starting out and need help with the basics?
# *   Do you have a specific problem you're trying to solve?
# *   Are you looking for an explanation of a particular concept (like loops, functions, classes, etc.)?
# *   Do you have some code that isn't working as expected?
#
# The more details you can give me, the better I can assist you! 😊

# %%
#send a follow up message
response = chat_session.send_message("What are some common list operations?")
print(response.text)
# Out:
# That's a great question! Python lists are incredibly versatile and fundamental to working with data. Here are some of the most common and essential list operations, categorized for clarity, along with examples:
#
# Let's start with a sample list:
# ```python
# my_list = [10, 20, 30, 40, 50]
# ```
#
# ---
#
# ### 1. Accessing Elements
#
# *   **Indexing:** Get an element by its position (index). Indices start from `0`.
#     *   `my_list[index]`
#     *   Negative indices count from the end (`-1` is the last element).
#     ```python
#     print(my_list[0])   # Output: 10 (first element)
#     print(my_list[4])   # Output: 50 (fifth element)
#     print(my_list[-1])  # Output: 50 (last element)
#     print(my_list[-2])  # Output: 40 (second to last)
#     ```
#
# *   **Slicing:** Get a sub-list (a "slice") of elements.
#     *   `my_list[start:end]` (elements from `start` up to, but not including, `end`)
#     *   `my_list[start:]` (from `start` to the end)
#     *   `my_list[:end]` (from the beginning up to `end`)
#     *   `my_list[::step]` (every `step`-th element)
#     ```python
#     print(my_list[1:4])   # Output: [20, 30, 40]
#     print(my_list[2:])    # Output: [30, 40, 50]
#     print(my_list[:3])    # Output: [10, 20, 30]
#     print(my_list[::2])   # Output: [10, 30, 50] (every second element)
#     print(my_list[::-1])  # Output: [50, 40, 30, 20, 10] (reverse the list)
#     ```
#
# ---
#
# ### 2. Modifying Elements
#
# *   **Assigning a new value:** Change an element at a specific index.
#     *   `my_list[index] = new_value`
#     ```python
#     my_list[2] = 35
#     print(my_list) # Output: [10, 20, 35, 40, 50]
#     ```
#
# ---
#
# ### 3. Adding Elements
#
# *   **`.append(item)`:** Adds an `item` to the end of the list.
#     ```python
#     my_list.append(60)
#     print(my_list) # Output: [10, 20, 35, 40, 50, 60]
#     ```
#
# *   **`.insert(index, item)`:** Inserts an `item` at a specific `index`.
#     ```python
#     my_list.insert(0, 5) # Insert 5 at the beginning
#     print(my_list) # Output: [5, 10, 20, 35, 40, 50, 60]
#     ```
#
# *   **`.extend(iterable)`:** Adds all elements from another `iterable` (like another list, tuple, etc.) to the end of the current list.
#     ```python
#     another_list = [70, 80]
#     my_list.extend(another_list)
#     print(my_list) # Output: [5, 10, 20, 35, 40, 50, 60, 70, 80]
#     ```
#
# *   **`+` (Concatenation):** Creates a *new* list by joining two or more lists.
#     ```python
#     list1 = [1, 2]
#     list2 = [3, 4]
#     combined_list = list1 + list2
#     print(combined_list) # Output: [1, 2, 3, 4]
#     print(list1)         # Output: [1, 2] (list1 is unchanged)
#     ```
#
# ---
#
# ### 4. Removing Elements
#
# *   **`.remove(value)`:** Removes the *first* occurrence of a specified `value`. Raises a `ValueError` if the value is not found.
#     ```python
#     my_list.remove(35)
#     print(my_list) # Output: [5, 10, 20, 40, 50, 60, 70, 80]
#     ```
#
# *   **`.pop([index])`:** Removes and *returns* the element at a specified `index`. If no index is given, it removes and returns the last element.
#     ```python
#     removed_item = my_list.pop(0) # Remove element at index 0
#     print(removed_item) # Output: 5
#     print(my_list)      # Output: [10, 20, 40, 50, 60, 70, 80]
#
#     last_item = my_list.pop() # Remove the last element
#     print(last_item)    # Output: 80
#     print(my_list)      # Output: [10, 20, 40, 50, 60, 70]
#     ```
#
# *   **`del list[index]` or `del list[slice]`:** Deletes an element or a slice of elements by index. Does not return the deleted items.
#     ```python
#     del my_list[0] # Delete element at index 0
#     print(my_list) # Output: [20, 40, 50, 60, 70]
#
#     del my_list[1:3] # Delete elements from index 1 up to (not including) 3
#     print(my_list)   # Output: [20, 70]
#     ```
#
# *   **`.clear()`:** Removes all elements from the list, making it empty.
#     ```python
#     my_list.clear()
#     print(my_list) # Output: []
#     ```
#
# ---
#
# ### 5. Information and Queries
#
# *   **`len(list)`:** Returns the number of elements in the list. (This is a built-in function, not a list method).
#     ```python
#     my_list = [10, 20, 30, 40, 50]
#     print(len(my_list)) # Output: 5
#     ```
#
# *   **`value in list`:** Checks if a `value` exists in the list (returns `True` or `False`).
#     ```python
#     print(30 in my_list)   # Output: True
#     print(99 in my_list)   # Output: False
#     ```
#
# *   **`.count(value)`:** Returns the number of times a specified `value` appears in the list.
#     ```python
#     my_list_dupes = [1, 2, 2, 3, 1, 4]
#     print(my_list_dupes.count(1)) # Output: 2
#     print(my_list_dupes.count(5)) # Output: 0
#     ```
#
# *   **`.index(value, [start, end])`:** Returns the index of the *first* occurrence of a `value`. Can specify an optional search range. Raises a `ValueError` if the value is not found.
#     ```python
#     print(my_list.index(30)) # Output: 2
#     # print(my_list.index(99)) # Raises ValueError
#     ```
#
# *   **`min(list)`, `max(list)`, `sum(list)`:** Built-in functions to find the minimum, maximum, or sum of elements in a list (for numeric lists).
#     ```python
#     print(min(my_list)) # Output: 10
#     print(max(my_list)) # Output: 50
#     print(sum(my_list)) # Output: 150
#     ```
#
# ---
#
# ### 6. Ordering and Sorting
#
# *   **`.sort()`:** Sorts the list *in-place* (modifies the original list).
#     *   `list.sort(reverse=True)` for descending order.
#     ```python
#     nums = [3, 1, 4, 1, 5, 9, 2]
#     nums.sort()
#     print(nums) # Output: [1, 1, 2, 3, 4, 5, 9]
#
#     nums.sort(reverse=True)
#     print(nums) # Output: [9, 5, 4, 3, 2, 1, 1]
#     ```
#
# *   **`sorted(list)`:** Returns a *new* sorted list, leaving the original list unchanged.
#     *   `sorted(list, reverse=True)` for descending order.
#     ```python
#     original_nums = [3, 1, 4, 1, 5]
#     new_sorted_nums = sorted(original_nums)
#     print(new_sorted_nums) # Output: [1, 1, 3, 4, 5]
#     print(original_nums)   # Output: [3, 1, 4, 1, 5] (original is unchanged)
#     ```
#
# *   **`.reverse()`:** Reverses the elements of the list *in-place*.
#     ```python
#     letters = ['a', 'b', 'c']
#     letters.reverse()
#     print(letters) # Output: ['c', 'b', 'a']
#     ```
#
# ---
#
# ### 7. Copying Lists
#
# *   **`new_list = old_list.copy()`** or **`new_list = old_list[:]`**: Creates a *shallow copy* of the list. This is generally what you want.
#     ```python
#     original = [1, 2, 3]
#     copied_list = original.copy()
#     # or: copied_list = original[:]
#
#     copied_list.append(4)
#     print(original)    # Output: [1, 2, 3]
#     print(copied_list) # Output: [1, 2, 3, 4]
#     ```
#     **Important Note:** For lists containing nested lists or mutable objects, a shallow copy means the nested objects are still references to the original. For a truly independent copy, you'd need `import copy; copy.deepcopy(original_list)`.
#
# ---
#
# ### 8. Iterating
#
# *   **`for item in list:`:** Loop through each element in the list.
#     ```python
#     fruits = ["apple", "banana", "cherry"]
#     for fruit in fruits:
#         print(f"I love {fruit}s!")
#     # Output:
#     # I love apples!
#     # I love bananas!
#     # I love cherrys!
#     ```
#
# ---
#
# These are the most frequent operations you'll perform with Python lists. Mastering them will make working with collections of data much easier! Let me know if you'd like to dive deeper into any specific one!

# %%
#access full conversation history at any time
for message in chat_session.get_history():
    print(f"{message.role}: {message.parts[0].text}")

# %%
#step 4: Stream responses for dynamic user experience

response = chat_session.send_message_stream("Tell me a story.")
for chunk in response:
    print(chunk.text, end="")
# Out:
# Okay, settle in! Here's a little tale for you:
#
# ***
#
# Elara was a creature of quiet habits and whispered pages. Her domain was the grand, oak-paneled city library, a place where the scent of aged paper and forgotten stories hung thick in the air like a benevolent fog. She knew the library's every creak and groan, its dusty corners, and its sun-dappled nooks.
#
# One particularly blustery Tuesday, as the wind howled outside, rattling the tall windows, Elara was reorganizing the seldom-visited "Obscure Cartography" section. Tucked behind a towering atlas of forgotten sea routes, she found it: a small, unassuming wooden box, intricately carved but utterly plain. It had no lock, no latch, just a smooth, almost warm surface.
#
# Curiosity, a rare but potent spark in Elara, compelled her to open it. Inside, nestled on a bed of faded velvet, was not a map, nor a scroll, but a single, perfectly ordinary-looking pocket watch. It was silver, unadorned, with a clear glass face and simple Roman numerals. No hands.
#
# "Odd," she murmured, turning it over. There was no winding mechanism, no hinge to open the back. It was just... a watch, without hands, in a box. She set it on her desk, beside her half-finished cup of Earl Grey.
#
# A moment later, as Elara turned to retrieve a misplaced volume, a faint *tick* sounded from the desk. She looked back. The watch. It still had no hands, but a soft, ethereal glow emanated from within its crystal face, and within that glow, tiny, shimmering motes of light began to dance.
#
# Another *tick*. This time, Elara distinctly heard a distant, cheerful *clink* – like small bells. A warm, yeasty scent, reminiscent of freshly baked bread, wafted gently from the watch.
#
# She peered closer. The motes of light within the watch face weren't random; they were forming miniature scenes, fleeting as breath on glass. One moment, she saw a microscopic ship sailing a silver sea, then a tiny, mischievous cat batting at an even tinier ball of yarn.
#
# Each tick brought a new sensory experience. A whisper of wind, the faint scent of lilac, the sound of distant laughter, a fleeting sensation of cool marble underfoot. The watch, Elara realized with a growing wonder, wasn't keeping time. It was *sampling* it. It was plucking tiny, forgotten moments from the past, or perhaps, the potential moments of the future, and presenting them in a beautiful, ephemeral dance.
#
# Elara didn't tell anyone about her discovery. The watch didn't need to be wound, didn't need batteries. It simply *ticked* when it pleased, sending out its subtle, enchanting signals.
#
# She started leaving the watch in different places around the library. Sometimes, it was on the children's reading table, and the little ones would suddenly burst into unprompted giggles, or point to nothing, saying, "Did you see that sparkle?"
#
# Sometimes, it was near a stressed student, and a gentle, soothing melody would fill the air, unnoticed by others, but subtly easing their furrowed brows.
#
# Elara herself would often find the watch near her, letting its tiny, perfect moments wash over her after a long day. A forgotten sunset, the chirp of a long-extinct bird, the momentary joy of someone finding a beloved book.
#
# The old library, once just a building of quiet discipline, began to hum with an unidentifiable, gentle magic. Patrons felt a little more at ease, a little more inspired. They couldn't explain it, but the air felt lighter, the light seemed brighter, and the stories within the pages seemed to whisper just a little louder.
#
# And Elara, the quiet librarian with her spectacles perched on her nose, would simply smile. She knew that the greatest magic wasn't in grand displays or booming spells, but in the tiny, perfect moments that, like the ticks of a handless watch, made the fabric of life just a little more wonderful.
#
# The watch remained her secret, a silent testament to the countless tiny treasures that exist, if only one knows how to listen, and where to look.

# %%
#step 5: Chatting directly with a REST API
#error 403

# %%bash

curl "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-preview-05-20:generateContent?key=$GEMINI_API_KEY" \
  -H 'Content-Type: application/json' \
  -d '{
    "system_instruction": {
      "parts": [{"text": "You are a helpful travel advisor."}]
    },
    "contents": [
      {"role": "user", "parts": [{"text": "Hi, I am going to take a trip."}]},
    {"role": "model", "parts": [{"text": "Great! Where are you thinking of going?"}]}, #?? what is this
    {"role": "user", "parts": [{"text": "Maybe somewhere tropical."}]}
  ]
}' 2> /dev/null

# %%
#single-turn with function declarations

#error 403

# %%bash

curl "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-preview-05-20:generateContent?key=$GEMINI_API_KEY" \
  -H 'Content-Type: application/json' \
  -d '{
    "system_instruction": {
      "parts": [{"text": "You are a helpful travel advisor."}]
    },
    "contents": [
      {"role": "user", "parts": [{"text": "Hi, I want to take a trip to somewhere tropical."}]}
  ],
  "tools": [
    "function_declarations": [
      {
        "name": "get_location",
        "description": "Compile a list of topic tropical destinations around the world.",
        "parameters": {
          "type":"object",
          "properties":{
            "location":{
              "type":"string",
              "description":"The city and country of the location."
            },
            "events":{
              "type":"string",
              "description":"The top sight-seeing events in the location."
            }
            },
            "required":["location"]
          }
        },
        {
        "name": "get_planes",
        "description": "Compile a list of planes traveling to tropical destinations.",
        "parameters": {
          "type":"object",
          "properties":{
            "location":{
              "type":"string",
              "description":"The city and country details of the trip."
            },
            "description":{
              "type":"string",
              "description":"Flight details, including airline, takeoff and landing time."
            }
            },
            "required":["location"]
          }
        }
    ]
  ]
}'
2> /dev/null
